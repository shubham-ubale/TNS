# %% [markdown]
# # Amazon Sales Dataset - Practice Questions
#
# **Student Name:** _________________
# **Date:** _________________
#
# ---
#
# ## Instructions
# - This notebook contains practice questions based on the Amazon Sales EDA session
# - Complete each question in the provided code cells
# - Hints are provided for each question
# - Try to solve without looking at hints first
# - Load the `amazon.csv` dataset to answer these questions
#
# ---

# %% [markdown]
# ## Section 1: Data Loading and Initial Exploration (20 marks)

# %% [markdown]
# ### Question 1.1 (3 marks)
# Load the Amazon sales dataset (`amazon.csv`) and display the first 10 rows.
#
# **Hint:** Use `pd.read_csv()` and `.head()` method

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
plt.style.use('default')
# Your code here

df = pd.read_csv('amazon.csv')
df.head(10)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 9  B082LZGK39  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %% [markdown]
# ### Question 1.2 (3 marks)
# Display the shape of the dataset and print the column names.
#
# **Hint:** Use `.shape` attribute and `.columns` attribute

# %%
# Your code here
#shape
print("Dataset shape: ", df.shape)
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

#column names
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset shape:  (1465, 16)
# Rows: 1465, Columns: 16
#
# Columns:
# ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link']

# %% [markdown]
# ### Question 1.3 (4 marks)
# Get detailed information about the dataset including:
# - Data types of each column
# - Number of non-null values
# - Memory usage
#
# **Hint:** Use `.info()` method

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# ### Question 1.4 (5 marks)
# Generate statistical summary of all numerical columns in the dataset.
#
# **Hint:** Use `.describe()` method

# %%
# Your code here
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# ### Question 1.5 (5 marks)
# Check for missing values in the dataset. Display:
# - Total missing values per column
# - Percentage of missing values per column
#
# **Hint:** Use `.isnull().sum()` and calculate percentage = (missing/total)*100

# %%
# Your code here
#missing
missing = df.isnull().sum()
print("Missing Value:\n", missing)

#percentage
pct = (missing / len(df)) * 100
print("\nPercentage:\n", pct)

#combined
pd.DataFrame({"Count": missing, "Percentage": pct})
# Out:
# Missing Value:
#  product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64
#
# Percentage:
#  product_id             0.000000
# product_name           0.000000
# category               0.000000
# discounted_price       0.000000
# actual_price           0.000000
# discount_percentage    0.000000
# rating                 0.000000
# rating_count           0.136519
# about_product          0.000000
# user_id                0.000000
# user_name              0.000000
# review_id              0.000000
# review_title           0.000000
# review_content         0.000000
# img_link               0.000000
# ...

# %% [markdown]
# ---
# ## Section 2: Data Cleaning and Manipulation (25 marks)

# %% [markdown]
# ### Question 2.1 (5 marks)
# Check for duplicate rows in the dataset. If duplicates exist, remove them and display the new shape.
#
# **Hint:** Use `.duplicated().sum()` to check, then `.drop_duplicates()` to remove

# %%
# Your code here
print("Original:", df.shape)
print("Duplicated:", df.duplicated().sum())

df = df.drop_duplicates()
print("After removing:", df.shape)
# Out:
# Original: (1465, 16)
# Duplicated: 0
# After removing: (1465, 16)

# %% [markdown]
# ### Question 2.2 (5 marks)
# Handle missing values in the dataset using appropriate methods:
# - For numerical columns: Fill with mean or median
# - For categorical columns: Fill with mode or 'Unknown'
#
# **Hint:** Use `.fillna()` method with `.mean()`, `.median()`, or `.mode()[0]`

# %%
# Your code here
#numerical - median
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].median(), inplace=True)

#categorical - mode
cat_cols = df.select_dtypes(include=["object"]).columns
for col in cat_cols:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].mode()[0], inplace=True)

print("Missing after cleaning:", df.isnull().sum().sum())
# Out:
# Missing after cleaning: 0

# %% [markdown]
# ### Question 2.3 (5 marks)
# Create a new column called `discount_percentage` that calculates the discount percentage using actual_price and discounted_price.
#
# **Formula:** discount% = ((actual_price - discounted_price) / actual_price) * 100
#
# **Hint:** Create new column using: `df['new_column'] = calculation`

# %%
# Your code here
df['actual_price'] = df['actual_price'].replace('[₹,]', '', regex=True).astype(float)
df['discounted_price'] = df['discounted_price'].replace('[₹,]', '', regex=True).astype(float)


df['discount_percentage'] = ((df['actual_price'] - df['discounted_price']) / df['actual_price']) * 100
df['discount_percentage'] = df['discount_percentage'].round(2)
df[['actual_price', 'discounted_price', 'discount_percentage']].head(10)
# Out:
#    actual_price  discounted_price  discount_percentage
# 0        1099.0            399.00                63.69
# 1         349.0            199.00                42.98
# 2        1899.0            199.00                89.52
# 3         699.0            329.00                52.93
# 4         399.0            154.00                61.40
# 5        1000.0            149.00                85.10
# 6         499.0            176.63                64.60
# 7         299.0            229.00                23.41
# 8         999.0            499.00                50.05
# 9         299.0            199.00                33.44

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# ### Question 2.4 (5 marks)
# Filter the dataset to show only products with:
# - Rating greater than or equal to 4.0
# - Discount percentage greater than 50%
#
# Display the first 5 rows of filtered data.
#
# **Hint:** Use boolean indexing: `df[(condition1) & (condition2)]`

# %%
# Your code here
#first change their datatype and then do comparison
# df['rating'] = df['rating'].str.replace('|',1.0).astype('float64')

# df['discount_percentage'] = df['discount_percentage'].astype(float)


filtered = df[(df['rating'] >= 4.0) & (df['discount_percentage'] > 50)]
print(f"Filtered: {len(filtered)}")
filtered.head()
# Out:
# Filtered: 535
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...            399.00
# 3  Computers&Accessories|Accessories&Peripherals|...            329.00
# 4  Computers&Accessories|Accessories&Peripherals|...            154.00
# 6  Computers&Accessories|Accessories&Peripherals|...            176.63
# 8  Computers&Accessories|NetworkingDevices|Networ...            499.00
#
#    actual_price  discount_percentage  rating rating_count  \
# 0        1099.0                63.69     4.2       24,269
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating rating_count  \
# 0        1099.0                63.69    4.2       24,269
# ...

# %% [markdown]
# ### Question 2.5 (5 marks)
# Sort the dataset by `discounted_price` in descending order and display the top 10 most expensive products.
#
# **Hint:** Use `.sort_values()` with `ascending=False` parameter

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 3: Data Analysis and Aggregation (30 marks)

# %% [markdown]
# ### Question 3.1 (5 marks)
# Find the following:
# - Total number of unique product categories
# - List all unique categories
#
# **Hint:** Use `.nunique()` to count and `.unique()` to list

# %%
# Your code here

# %% [markdown]
# ### Question 3.2 (6 marks)
# Find which product category has:
# - The highest number of products
# - The lowest number of products
#
# **Hint:** Use `.value_counts()` method on the category column

# %%
# Your code here

# %% [markdown]
# ### Question 3.3 (6 marks)
# Calculate the average discounted price for each product category. Display results sorted by average price in descending order.
#
# **Hint:** Use `.groupby()` with `.mean()` and `.sort_values()`

# %%
# Your code here

# %% [markdown]
# ### Question 3.4 (7 marks)
# For each category, calculate:
# - Average rating
# - Average discount percentage
# - Total number of products
#
# Display this as a summary table.
#
# **Hint:** Use `.groupby()` with `.agg()` and pass a dictionary of aggregations

# %%
# Your code here

# %% [markdown]
# ### Question 3.5 (6 marks)
# Find the product with:
# - Highest rating
# - Lowest price
# - Maximum discount percentage
#
# Display the product name and relevant values.
#
# **Hint:** Use `.loc[df['column'].idxmax()]` or `.loc[df['column'].idxmin()]`

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 4: Data Visualization (25 marks)

# %% [markdown]
# ### Question 4.1 (5 marks)
# Create a histogram showing the distribution of product ratings.
#
# **Requirements:**
# - Use 20 bins
# - Add title and axis labels
# - Use a color of your choice
#
# **Hint:** Use `plt.hist()` or `df['column'].hist()`

# %%
# Your code here

# %% [markdown]
# ### Question 4.2 (6 marks)
# Create a bar chart showing the top 10 product categories by count.
#
# **Requirements:**
# - Sort in descending order
# - Add title and axis labels
# - Rotate x-axis labels for better readability
#
# **Hint:** Use `.value_counts().head(10).plot(kind='bar')` or `plt.bar()`

# %%
# Your code here

# %% [markdown]
# ### Question 4.3 (7 marks)
# Create a scatter plot showing the relationship between actual_price and discounted_price.
#
# **Requirements:**
# - Color points by rating (use a colormap)
# - Add colorbar to show rating scale
# - Add title and axis labels
# - Set figure size to (10, 6)
#
# **Hint:** Use `plt.scatter()` with `c=` parameter for colors and `plt.colorbar()`

# %%
# Your code here

# %% [markdown]
# ### Question 4.4 (7 marks)
# Create a boxplot to compare the distribution of discounted prices across different categories.
#
# **Requirements:**
# - Show only top 5 categories (by product count)
# - Rotate x-axis labels
# - Add title and axis labels
# - Use seaborn for better styling
#
# **Hint:** Use `sns.boxplot()` with filtered data

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 5: String Operations and Text Analysis (20 marks)

# %% [markdown]
# ### Question 5.1 (4 marks)
# Extract the first word from the product name and create a new column called `product_type`.
#
# **Example:** "Samsung Galaxy Phone" → "Samsung"
#
# **Hint:** Use `.str.split()` with `expand=True` and select the first element, or use `.str.extract()`

# %%
# Your code here

# %% [markdown]
# ### Question 5.2 (4 marks)
# Find all products where the product name contains the word "wireless" (case-insensitive).
# Display the count and first 5 products.
#
# **Hint:** Use `.str.contains()` with `case=False` parameter

# %%
# Your code here

# %% [markdown]
# ### Question 5.3 (4 marks)
# Calculate the average length of product names for each category. Which category has the longest product names on average?
#
# **Hint:** Use `.str.len()` to get string length, then group by category and find mean

# %%
# Your code here

# %% [markdown]
# ### Question 5.4 (4 marks)
# Convert all product names to uppercase and display the first 10.
#
# **Hint:** Use `.str.upper()` method

# %%
# Your code here

# %% [markdown]
# ### Question 5.5 (4 marks)
# Count how many products have the word "Pro" or "Plus" in their name.
#
# **Hint:** Use `.str.contains()` with the `|` (OR) operator in regex pattern

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 6: Advanced Filtering and Conditional Logic (20 marks)

# %% [markdown]
# ### Question 6.1 (5 marks)
# Create a new column called `price_category` based on discounted_price:
# - "Budget" if price < 500
# - "Mid-Range" if price between 500 and 2000
# - "Premium" if price > 2000
#
# Display the count of products in each price category.
#
# **Hint:** Use `np.where()` or `pd.cut()` for categorization

# %%
# Your code here

# %% [markdown]
# ### Question 6.2 (5 marks)
# Create a column called `rating_label`:
# - "Excellent" if rating >= 4.5
# - "Good" if rating >= 4.0 and < 4.5
# - "Average" if rating >= 3.0 and < 4.0
# - "Poor" if rating < 3.0
#
# **Hint:** Use multiple `np.where()` nested or use `pd.cut()` with custom labels

# %%
# Your code here

# %% [markdown]
# ### Question 6.3 (5 marks)
# Find products that meet ALL of the following criteria:
# - Rating >= 4.2
# - Discount percentage > 40%
# - Discounted price < 1500
#
# Display count and show top 5 by rating.
#
# **Hint:** Use multiple conditions with `&` operator

# %%
# Your code here

# %% [markdown]
# ### Question 6.4 (5 marks)
# Create a column called `deal_quality` that combines rating and discount:
# - "Best Deal" if rating >= 4.5 AND discount >= 50%
# - "Good Deal" if rating >= 4.0 AND discount >= 30%
# - "Fair Deal" for all others
#
# Show the distribution of deal quality.
#
# **Hint:** Use nested `np.where()` conditions

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 7: Data Transformation and Feature Engineering (20 marks)

# %% [markdown]
# ### Question 7.1 (5 marks)
# Calculate the total savings amount (actual_price - discounted_price) for each product.
# Find the top 10 products with maximum savings.
#
# **Hint:** Create new column with subtraction, then use `.nlargest()`

# %%
# Your code here

# %% [markdown]
# ### Question 7.2 (5 marks)
# Normalize the rating column to a 0-1 scale using Min-Max normalization.
#
# **Formula:** normalized = (value - min) / (max - min)
#
# **Hint:** Use `.min()` and `.max()` methods

# %%
# Your code here

# %% [markdown]
# ### Question 7.3 (5 marks)
# Create a pivot table showing:
# - Rows: Top 5 categories (by count)
# - Columns: price_category (Budget/Mid-Range/Premium)
# - Values: Average rating
#
# **Hint:** Use `pd.pivot_table()` with appropriate parameters

# %%
# Your code here

# %% [markdown]
# ### Question 7.4 (5 marks)
# Calculate the rank of each product within its category based on rating (highest rating = rank 1).
# Display the top 3 ranked products from any 2 categories.
#
# **Hint:** Use `.groupby()` with `.rank()` method, or use `.sort_values()` and `.head()`

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 8: Advanced Visualization (25 marks)

# %% [markdown]
# ### Question 8.1 (6 marks)
# Create a subplot with 2 rows and 2 columns showing:
# 1. Histogram of ratings
# 2. Histogram of discounted prices
# 3. Bar chart of top 5 categories
# 4. Pie chart of price_category distribution
#
# **Hint:** Use `plt.subplots(2, 2)` and plot on each axis

# %%
# Your code here

# %% [markdown]
# ### Question 8.2 (6 marks)
# Create a line plot showing average rating for each category, sorted by average rating.
#
# **Requirements:**
# - Add markers on the line
# - Add grid
# - Rotate x-axis labels
# - Add data labels on points
#
# **Hint:** Use `.plot(kind='line')` or `plt.plot()` with marker parameter

# %%
# Your code here

# %% [markdown]
# ### Question 8.3 (7 marks)
# Create a violin plot comparing the distribution of discount_percentage across different rating_labels (Excellent, Good, Average, Poor).
#
# **Requirements:**
# - Use seaborn
# - Add title and labels
# - Use a nice color palette
#
# **Hint:** Use `sns.violinplot()` with appropriate x and y parameters

# %%
# Your code here

# %% [markdown]
# ### Question 8.4 (6 marks)
# Create a count plot showing the distribution of products across price_category, with bars colored by rating_label.
#
# **Requirements:**
# - Use seaborn
# - Add legend
# - Add title
#
# **Hint:** Use `sns.countplot()` with hue parameter

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 9: Statistical Analysis (15 marks)

# %% [markdown]
# ### Question 9.1 (5 marks)
# Calculate and display the following for the discounted_price column:
# - Mean
# - Median
# - Mode
# - Standard Deviation
# - Variance
#
# **Hint:** Use `.mean()`, `.median()`, `.mode()`, `.std()`, `.var()`

# %%
# Your code here

# %% [markdown]
# ### Question 9.2 (5 marks)
# Calculate the 25th, 50th (median), and 75th percentiles for the rating column.
# Also identify the Interquartile Range (IQR).
#
# **Formula:** IQR = Q3 - Q1
#
# **Hint:** Use `.quantile()` method

# %%
# Your code here

# %% [markdown]
# ### Question 9.3 (5 marks)
# Detect outliers in the discounted_price column using the IQR method.
#
# **Outlier criteria:**
# - Lower bound: Q1 - 1.5 * IQR
# - Upper bound: Q3 + 1.5 * IQR
#
# Count how many outliers exist and display 5 sample outliers.
#
# **Hint:** Calculate bounds using quantiles and IQR, then filter

# %%
# Your code here

# %% [markdown]
# ---
# ## Bonus Section: Advanced Analysis (Optional - 10 bonus marks)

# %% [markdown]
# ### Bonus Question 1 (5 marks)
# Create a correlation heatmap for all numerical columns in the dataset.
#
# **Requirements:**
# - Use seaborn heatmap
# - Display correlation values on the heatmap
# - Use an appropriate color scheme
#
# **Hint:** Use `df.corr()` to get correlation matrix, then `sns.heatmap()` with `annot=True`

# %%
# Your code here

# %% [markdown]
# ### Bonus Question 2 (5 marks)
# Create a function that takes a category name as input and returns a summary report including:
# - Number of products
# - Average rating
# - Average price
# - Price range (min to max)
# - Average discount percentage
#
# Test your function with 2 different categories.
#
# **Hint:** Define a function with category as parameter, filter data, and calculate statistics

# %%
# Your code here

# %% [markdown]
# ### Bonus Question 3 (5 marks)
# Create a multi-category comparison chart using subplots:
# - Select 3 categories of your choice
# - Create 3 subplots (1 row, 3 columns)
# - Each subplot should show price vs rating scatter plot for that category
# - Color points by discount percentage
#
# **Hint:** Use `plt.subplots(1, 3)` and loop through categories

# %%
# Your code here

# %% [markdown]
# ### Bonus Question 4 (5 marks)
# Perform a cross-tabulation analysis:
# - Create a cross-tab between `price_category` and `rating_label`
# - Display the count of products in each combination
# - Visualize this using a heatmap
#
# **Hint:** Use `pd.crosstab()` and `sns.heatmap()`

# %%
# Your code here

# %% [markdown]
# ### Bonus Question 5 (5 marks)
# Create a recommendation system function:
# - Input: Maximum budget, minimum rating, category (optional)
# - Output: Top 5 recommended products sorted by rating then discount percentage
# - Test with budget=1000, rating=4.0, category of your choice
#
# **Hint:** Filter based on conditions, sort by multiple columns using `.sort_values()`

# %%
# Your code here

# %% [markdown]
# ---
# ## Submission Guidelines
#
# 1. **Complete all questions in Sections 1-9 (Total: 175 marks)**
# 2. **Bonus section is optional (25 additional marks)**
# 3. **Time allocation: 45 minutes**
# 4. Ensure all code cells run without errors
# 5. Add comments to explain your logic
# 6. Save your notebook with filename: `YourName_Amazon_Practice.ipynb`
# 7. Submit via the designated platform
#
# ### Recommended Time Management:
# - Section 1: 5 minutes
# - Section 2: 6 minutes
# - Section 3: 7 minutes
# - Section 4: 6 minutes
# - Section 5: 4 minutes
# - Section 6: 4 minutes
# - Section 7: 4 minutes
# - Section 8: 6 minutes
# - Section 9: 3 minutes
# - **Total: 45 minutes**
# - Bonus: If time permits
#
# ---
#
# ## Common Functions Quick Reference
#
# **Data Exploration:**
# - `df.head(n)` - First n rows
# - `df.tail(n)` - Last n rows
# - `df.shape` - Dimensions (rows, columns)
# - `df.info()` - Data types and memory info
# - `df.describe()` - Statistical summary
# - `df.columns` - Column names
# - `df.dtypes` - Data types of columns
#
# **Data Cleaning:**
# - `df.isnull().sum()` - Count missing values
# - `df.fillna(value)` - Fill missing values
# - `df.dropna()` - Drop rows with missing values
# - `df.drop_duplicates()` - Remove duplicate rows
# - `df.duplicated().sum()` - Count duplicates
#
# **Data Analysis:**
# - `df['col'].value_counts()` - Count unique values
# - `df['col'].nunique()` - Count of unique values
# - `df['col'].unique()` - List unique values
# - `df.groupby('col')` - Group data
# - `df.sort_values('col')` - Sort data
# - `df.loc[]` - Select by label
# - `df.iloc[]` - Select by position
# - `df.nlargest(n, 'col')` - Top n values
# - `df.nsmallest(n, 'col')` - Bottom n values
#
# **String Operations:**
# - `df['col'].str.lower()` - Convert to lowercase
# - `df['col'].str.upper()` - Convert to uppercase
# - `df['col'].str.contains('text')` - Check if contains text
# - `df['col'].str.split()` - Split string
# - `df['col'].str.len()` - String length
#
# **Statistical Functions:**
# - `df['col'].mean()` - Average
# - `df['col'].median()` - Median
# - `df['col'].mode()` - Mode
# - `df['col'].std()` - Standard deviation
# - `df['col'].var()` - Variance
# - `df['col'].quantile(0.25)` - Percentile
# - `df['col'].min()` - Minimum
# - `df['col'].max()` - Maximum
#
# **Aggregation:**
# - `df.groupby('col').mean()` - Group and calculate mean
# - `df.groupby('col').agg({'col1':'mean', 'col2':'sum'})` - Multiple aggregations
# - `pd.pivot_table(df, values, index, columns, aggfunc)` - Pivot table
# - `pd.crosstab(df['col1'], df['col2'])` - Cross tabulation
#
# **Visualization:**
# - `plt.plot()` - Line plot
# - `plt.hist()` - Histogram
# - `plt.bar()` - Bar chart
# - `plt.scatter()` - Scatter plot
# - `plt.pie()` - Pie chart
# - `plt.subplots(rows, cols)` - Multiple plots
# - `sns.boxplot()` - Box plot
# - `sns.violinplot()` - Violin plot
# - `sns.heatmap()` - Heatmap
# - `sns.countplot()` - Count plot
#
# **Conditional Operations:**
# - `np.where(condition, value_if_true, value_if_false)` - Conditional assignment
# - `pd.cut(series, bins, labels)` - Bin continuous data
# - Boolean indexing: `df[df['col'] > value]`
# - Multiple conditions: `df[(condition1) & (condition2)]`
#
# ---
#
# ## Tips for Success:
#
# 1. **Read questions carefully** - Understand what is being asked
# 2. **Check your output** - Verify your results make sense
# 3. **Use hints** - They guide you to the right approach
# 4. **Comment your code** - Explain your logic
# 5. **Test incrementally** - Run cells as you write them
# 6. **Manage time** - Don't spend too long on one question
# 7. **Use the reference** - Quick function lookup above
#
# ---
#
# **Good Luck! 🚀**
#
# *Remember: The goal is to demonstrate your understanding of data analysis concepts, not just to get the right answer. Show your thinking process!*
